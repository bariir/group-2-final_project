# %%
# %pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
CLIENT_ID="2945449546344725b6d087447f5dc3c6"
CLIENT_SECRET="6b105f60631e4956971032c14ba8bbb4"

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

results = sp.search(q='weezer', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'],track['id'])
# Out:
# 0 Island In The Sun 2MLHyLy5z5l5YRp7momlgw
# 1 Say It Ain't So 6VoIBz0VhCyz7OdEoRYDiA
# 2 Buddy Holly 3mwvKOyMmG77zZRunnxp9E
# 3 Undone - The Sweater Song 5WhtlIoxoZrMmuaWWEQhwV
# 4 Beverly Hills 1yKu2MhpwzDXXH2tzG6xoa
# 5 Africa 3ZPKocroJIcnHGcnJVlLKD
# 6 Hash Pipe 2mPMFJvQ0v27gVqe5b6nDn
# 7 I Just Threw Out The Love Of My Dreams 35SRuRfp5BvD1yArmXKNHO
# 8 All My Favorite Songs (feat. AJR) 3A6nR4GSolo160nu7xtDk7
# 9 Enter Sandman 6fwMnm8o21YXOgvSoKA9Fz
# 10 Pork And Beans 7wclPheMJAUKn2njmO2s3A
# 11 My Name Is Jonas 4nzyOwogJuWn1s6QuGFZ6w
# 12 Take on Me 1ZB2qWsheGabSEYvBYxjKn
# 13 Pink Triangle 6qQGxKyy6LcyZVsWn93lyS
# 14 Lost in the Woods - Weezer Version 227zkOoNpqRrzEPxvVRiF5
# 15 Everybody Wants to Rule the World 3gEoKDn0uhb9qqLwC16tly
# 16 Only In Dreams 3DkHNCA4QRBQgTzF2T18hm
# 17 (If You're Wondering If I Want You To) I Want You To 09aDV0TC2RfWFU5IwZfIdG
# 18 Records 23ZmKlucJRQrdR0QItAafL
# 19 A Little Bit of Love 0eLXFaZoGjVbzNmMd4LpmA

# %%
sp.audio_features(tracks=['2MLHyLy5z5l5YRp7momlgw'])
# Out:
# [{'danceability': 0.654,
#   'energy': 0.81,
#   'key': 4,
#   'loudness': -6.26,
#   'mode': 0,
#   'speechiness': 0.0288,
#   'acousticness': 0.00719,
#   'instrumentalness': 0.00251,
#   'liveness': 0.165,
#   'valence': 0.661,
#   'tempo': 114.623,
#   'type': 'audio_features',
#   'id': '2MLHyLy5z5l5YRp7momlgw',
#   'uri': 'spotify:track:2MLHyLy5z5l5YRp7momlgw',
#   'track_href': 'https://api.spotify.com/v1/tracks/2MLHyLy5z5l5YRp7momlgw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MLHyLy5z5l5YRp7momlgw',
#   'duration_ms': 200307,
#   'time_signature': 4}]

# %%
artist_name = ['er','er','eee']
for name in artist_name: 
    results = sp.search(q=name, limit=20)
    for idx, track in enumerate(results['tracks']['items']):
        print(idx, track['name'],track['id'])
        print(sp.audio_features(tracks=[track['id']]))

# %%
results = sp.search(q='weezer', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'],track['id'])
    print(sp.audio_features(tracks=[track['id']]))
# Out:
# 0 Island In The Sun 2MLHyLy5z5l5YRp7momlgw
# [{'danceability': 0.654, 'energy': 0.81, 'key': 4, 'loudness': -6.26, 'mode': 0, 'speechiness': 0.0288, 'acousticness': 0.00719, 'instrumentalness': 0.00251, 'liveness': 0.165, 'valence': 0.661, 'tempo': 114.623, 'type': 'audio_features', 'id': '2MLHyLy5z5l5YRp7momlgw', 'uri': 'spotify:track:2MLHyLy5z5l5YRp7momlgw', 'track_href': 'https://api.spotify.com/v1/tracks/2MLHyLy5z5l5YRp7momlgw', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MLHyLy5z5l5YRp7momlgw', 'duration_ms': 200307, 'time_signature': 4}]
# 1 Say It Ain't So 6VoIBz0VhCyz7OdEoRYDiA
# ...

# %%
sp.artist_top_tracks(artist_id,country='US')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6g/6jvgm8tx7cq144_29px4zwrw0000gn/T/ipykernel_1026/384829191.py in <module>
# ----> 1 sp.artist_top_tracks(artist_id,country='US')
#
# NameError: name 'artist_id' is not defined

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=weezer&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'},
#        'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu',
#        'id': '3jOstUTkEu2JkjvRdBA5Gu',
#        'name': 'Weezer',
#        'type': 'artist',
#        'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
# ...
